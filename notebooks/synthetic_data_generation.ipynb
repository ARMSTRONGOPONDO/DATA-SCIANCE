# %% [markdown]
# # Synthetic Kenyan Fraud Data Generation
#
# This notebook generates realistic synthetic transaction data with fraud patterns based on Kenyan demographics and transaction behaviors.

# %%
# Install required packages (if needed)
# !pip install faker pandas numpy

# %%
import pandas as pd
import numpy as np
from faker import Faker
import random
from datetime import datetime, timedelta

# Initialize Faker
fake = Faker()

# For reproducibility
np.random.seed(42)
random.seed(42)

# %% [markdown]
# ## Define Kenya-specific data generators

# %%
# Import code from src/data_generation.py here
# or run !python ../src/data_generation.py
