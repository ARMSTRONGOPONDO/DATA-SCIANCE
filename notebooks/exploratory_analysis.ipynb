# %% [markdown]
# # Kenyan Fraud Data Exploratory Analysis
#
# This notebook explores patterns in the synthetic Kenyan transaction data, focusing on fraud indicators and visualization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
plt.style.use('ggplot')
sns.set(font_scale=1.2)
sns.set_style("whitegrid")

# %% [markdown]
# ## Load the dataset

# %%
# Load the synthetic dataset
df = pd.read_csv('../data/kenyan_fraud_data.csv')
df.head()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Basic statistics
print(f"Dataset shape: {df.shape}")
print(f"Fraud rate: {df['is_fraud'].mean():.2%}")
